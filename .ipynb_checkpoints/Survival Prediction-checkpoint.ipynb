# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## DATA ANALYSIS

# %%
df = pd.read_csv('Titanic Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare  ... Embarked WikiId  \
# 0        0         A/5 21171   7.2500  ...        S  691.0
# 1        0          PC 17599  71.2833  ...        C   90.0
# 2        0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3        0            113803  53.1000  ...        S  127.0
# 4        0            373450   8.0500  ...        S  627.0
# ..     ...               ...      ...  ...      ...    ...
# 886      0            211536  13.0000  ...        S  514.0
# 887      0            112053  30.0000  ...        S  137.0
# 888      2        W./C. 6607  23.4500  ...        S  910.0
# 889      0            111369  30.0000  ...        C   28.0
# 890      0            370376   7.7500  ...        Q  783.0
#
#                                       Name_wiki Age_wiki  \
# 0                       Braund, Mr. Owen Harris     22.0
# 1    Cumings, Mrs. Florence Briggs (née Thayer)     35.0
# 2                         Heikkinen, Miss Laina     26.0
# 3            Futrelle, Mrs. Lily May (née Peel)     35.0
# 4                      Allen, Mr. William Henry     35.0
# ..                                          ...      ...
# 886                     Montvila, Father Juozas     27.0
# 887                 Graham, Miss Margaret Edith     19.0
# 888             Johnston, Miss Catherine Nellie      7.0
# 889                       Behr, Mr. Karl Howell     26.0
# 890                      Dooley, Mr. Patrick J.     43.0
#
#                                Hometown      Boarded  \
# 0            Bridgerule, Devon, England  Southampton
# 1                New York, New York, US    Cherbourg
# 2                    Jyväskylä, Finland  Southampton
# 3           Scituate, Massachusetts, US  Southampton
# 4    Birmingham, West Midlands, England  Southampton
# ..                                  ...          ...
# 886              Gudinė, Lithuania [76]  Southampton
# 887          Greenwich, Connecticut, US  Southampton
# 888     Thornton Heath, London, England  Southampton
# 889              New York, New York, US    Cherbourg
# 890     Patrickswell, Limerick, Ireland   Queenstown
#
#                                  Destination Lifeboat Body Class
# 0    Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0
# 1                     New York, New York, US        4  NaN   1.0
# 2                              New York City      14?  NaN   3.0
# 3                Scituate, Massachusetts, US        D  NaN   1.0
# 4                              New York City      NaN  NaN   3.0
# ..                                       ...      ...  ...   ...
# 886             Worcester, Massachusetts, US      NaN  NaN   2.0
# 887               Greenwich, Connecticut, US        3  NaN   1.0
# 888              New London, Connecticut, US      NaN  NaN   3.0
# 889                   New York, New York, US        5  NaN   1.0
# 890                            New York City      NaN  NaN   3.0
#
# [891 rows x 21 columns]

# %%
df = df.drop(['WikiId', 'Name_wiki', 'Age_wiki', 'Hometown' , 'Boarded', 'Destination' , 'Lifeboat', 'Body', 'Class'], axis=1).copy()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                    Name   Sex  \
# count    891.000000  891.000000  891.000000                     891   891
# unique          NaN         NaN         NaN                     891     2
# top             NaN         NaN         NaN  Lefebre, Miss. Jeannie  male
# freq            NaN         NaN         NaN                       1   577
# mean     446.000000    0.383838    2.308642                     NaN   NaN
# std      257.353842    0.486592    0.836071                     NaN   NaN
# min        1.000000    0.000000    1.000000                     NaN   NaN
# 25%      223.500000    0.000000    2.000000                     NaN   NaN
# 50%      446.000000    0.000000    3.000000                     NaN   NaN
# 75%      668.500000    1.000000    3.000000                     NaN   NaN
# max      891.000000    1.000000    3.000000                     NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare        Cabin  \
# count   714.000000  891.000000  891.000000    891  891.000000          204
# unique         NaN         NaN         NaN    681         NaN          147
# top            NaN         NaN         NaN   1601         NaN  C23 C25 C27
# freq           NaN         NaN         NaN      7         NaN            4
# mean     29.699118    0.523008    0.381594    NaN   32.204208          NaN
# std      14.526497    1.102743    0.806057    NaN   49.693429          NaN
# min       0.420000    0.000000    0.000000    NaN    0.000000          NaN
# 25%      20.125000    0.000000    0.000000    NaN    7.910400          NaN
# 50%      28.000000    0.000000    0.000000    NaN   14.454200          NaN
# 75%      38.000000    1.000000    0.000000    NaN   31.000000          NaN
# max      80.000000    8.000000    6.000000    NaN  512.329200          NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
pd.isnull(df).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    float64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## DATA VISUALIZATION

# %% [markdown]
# ### Sex Feature

# %%
sns.barplot(x="Sex", y="Survived", data=df)
plt.show()

# %% [markdown]
# ### Pclass Feature

# %%
sns.barplot(x="Pclass", y="Survived", data=df)
plt.show()

# %% [markdown]
# ### SibSP Feature

# %%
sns.barplot(x="SibSp", y="Survived", data=df)
plt.show()

# %% [markdown]
# ### Parch Feature

# %%
sns.barplot(x="Parch", y="Survived", data=df)
plt.show()

# %% [markdown]
# ### Age Feature

# %%
bins = [0, 5, 12, 18, 24, 35, 60, np.inf]
labels = ['Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']

df['AgeGroup'] = pd.cut(df['Age'], bins, labels=labels)

sns.barplot(x="AgeGroup", y="Survived", data=df)
plt.show()

# %% [markdown]
# ### Cabin Feature

# %%
df['CabinBool'] = df['Cabin'].notnull().astype('int')

sns.barplot(x="CabinBool", y="Survived", data=df)
plt.show()

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ### Drop unnecessary Columns

# %%
df = df.drop(['PassengerId','Ticket', 'Cabin'], axis=1)

# %% [markdown]
# ### Embarked Feature

# %%
print("Number of people embarking in Southampton (S):", df[df["Embarked"] == "S"].shape[0])
print("Number of people embarking in Cherbourg (C):", df[df["Embarked"] == "C"].shape[0])
print("Number of people embarking in Queenstown (Q):", df[df["Embarked"] == "Q"].shape[0])
# Out:
# Number of people embarking in Southampton (S): 644
# Number of people embarking in Cherbourg (C): 168
# Number of people embarking in Queenstown (Q): 77

# %%
df['Embarked'] = df['Embarked'].fillna('S')

# %%
embarked_mapping = {"S": 1, "C": 2, "Q": 3}

df['Embarked'] = df['Embarked'].map(embarked_mapping)

df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0       3                            Braund, Mr. Owen Harris
# 1         1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0       3                             Heikkinen, Miss. Laina
# 3         1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886       0.0       2                              Montvila, Rev. Juozas
# 887       1.0       1                       Graham, Miss. Margaret Edith
# 888       0.0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0       1                              Behr, Mr. Karl Howell
# 890       0.0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare  Embarked     AgeGroup  CabinBool
# 0      male  22.0      1      0   7.2500         1      Student          0
# 1    female  38.0      1      0  71.2833         2        Adult          1
# 2    female  26.0      0      0   7.9250         1  Young Adult          0
# 3    female  35.0      1      0  53.1000         1  Young Adult          1
# 4      male  35.0      0      0   8.0500         1  Young Adult          0
# ..      ...   ...    ...    ...      ...       ...          ...        ...
# 886    male  27.0      0      0  13.0000         1  Young Adult          0
# 887  female  19.0      0      0  30.0000         1      Student          1
# 888  female   NaN      1      2  23.4500         1          NaN          0
# 889    male  26.0      0      0  30.0000         2  Young Adult          1
# 890    male  32.0      0      0   7.7500         3  Young Adult          0
#
# [891 rows x 11 columns]

# %% [markdown]
# ### Age Feature

# %%
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    
pd.crosstab(df['Title'], df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
df['Title'] = df['Title'].replace(['Lady', 'Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Jonkheer', 'Dona'], 'Rare')
    
df['Title'] = df['Title'].replace(['Countess', 'Lady', 'Sir'], 'Royal')
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')

df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.285714
# 5   Royal  1.000000

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Royal": 5, "Rare": 6}

df['Title'] = df['Title'].map(title_mapping)
    
df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0       3                            Braund, Mr. Owen Harris
# 1         1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0       3                             Heikkinen, Miss. Laina
# 3         1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886       0.0       2                              Montvila, Rev. Juozas
# 887       1.0       1                       Graham, Miss. Margaret Edith
# 888       0.0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0       1                              Behr, Mr. Karl Howell
# 890       0.0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare  Embarked     AgeGroup  CabinBool  \
# 0      male  22.0      1      0   7.2500         1      Student          0
# 1    female  38.0      1      0  71.2833         2        Adult          1
# 2    female  26.0      0      0   7.9250         1  Young Adult          0
# 3    female  35.0      1      0  53.1000         1  Young Adult          1
# 4      male  35.0      0      0   8.0500         1  Young Adult          0
# ..      ...   ...    ...    ...      ...       ...          ...        ...
# 886    male  27.0      0      0  13.0000         1  Young Adult          0
# 887  female  19.0      0      0  30.0000         1      Student          1
# 888  female   NaN      1      2  23.4500         1          NaN          0
# 889    male  26.0      0      0  30.0000         2  Young Adult          1
# 890    male  32.0      0      0   7.7500         3  Young Adult          0
#
#      Title
# 0        1
# 1        3
# 2        2
# 3        3
# 4        1
# ..     ...
# 886      6
# 887      2
# 888      2
# 889      1
# 890      1
#
# [891 rows x 12 columns]

# %%
print('Mr Age Group(mode) -->', df[df["Title"] == 1]["AgeGroup"].mode()[0])
print('Miss Age Group(mode) -->', df[df["Title"] == 2]["AgeGroup"].mode()[0])
print('Mrs Age Group(mode) -->', df[df["Title"] == 3]["AgeGroup"].mode()[0])
print('Master Age Group(mode) -->', df[df["Title"] == 4]["AgeGroup"].mode()[0])
print('Royal Age Group(mode) -->', df[df["Title"] == 5]["AgeGroup"].mode()[0])
print('Rare Age Group(mode) -->', df[df["Title"] == 6]["AgeGroup"].mode()[0])
# Out:
# Mr Age Group(mode) --> Young Adult
# Miss Age Group(mode) --> Student
# Mrs Age Group(mode) --> Adult
# Master Age Group(mode) --> Baby
# Royal Age Group(mode) --> Young Adult
# Rare Age Group(mode) --> Adult

# %%
age_title_mapping = {1: "Young Adult", 2: "Student", 3: "Adult", 4: "Baby", 5: "Young Adult", 6: "Adult"}

df['AgeGroup'] = df['AgeGroup'].fillna((df["Title"].map(age_title_mapping)))

df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0       3                            Braund, Mr. Owen Harris
# 1         1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0       3                             Heikkinen, Miss. Laina
# 3         1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886       0.0       2                              Montvila, Rev. Juozas
# 887       1.0       1                       Graham, Miss. Margaret Edith
# 888       0.0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0       1                              Behr, Mr. Karl Howell
# 890       0.0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare  Embarked     AgeGroup  CabinBool  \
# 0      male  22.0      1      0   7.2500         1      Student          0
# 1    female  38.0      1      0  71.2833         2        Adult          1
# 2    female  26.0      0      0   7.9250         1  Young Adult          0
# 3    female  35.0      1      0  53.1000         1  Young Adult          1
# 4      male  35.0      0      0   8.0500         1  Young Adult          0
# ..      ...   ...    ...    ...      ...       ...          ...        ...
# 886    male  27.0      0      0  13.0000         1  Young Adult          0
# 887  female  19.0      0      0  30.0000         1      Student          1
# 888  female   NaN      1      2  23.4500         1      Student          0
# 889    male  26.0      0      0  30.0000         2  Young Adult          1
# 890    male  32.0      0      0   7.7500         3  Young Adult          0
#
#      Title
# 0        1
# 1        3
# 2        2
# 3        3
# 4        1
# ..     ...
# 886      6
# 887      2
# 888      2
# 889      1
# 890      1
#
# [891 rows x 12 columns]

# %%
age_mapping = {'Baby': 1, 'Child': 2, 'Teenager': 3, 'Student': 4, 'Young Adult': 5, 'Adult': 6, 'Senior': 7}

df['AgeGroup'] = df['AgeGroup'].map(age_mapping)

df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0       3                            Braund, Mr. Owen Harris
# 1         1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0       3                             Heikkinen, Miss. Laina
# 3         1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886       0.0       2                              Montvila, Rev. Juozas
# 887       1.0       1                       Graham, Miss. Margaret Edith
# 888       0.0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0       1                              Behr, Mr. Karl Howell
# 890       0.0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare  Embarked AgeGroup  CabinBool  Title
# 0      male  22.0      1      0   7.2500         1        4          0      1
# 1    female  38.0      1      0  71.2833         2        6          1      3
# 2    female  26.0      0      0   7.9250         1        5          0      2
# 3    female  35.0      1      0  53.1000         1        5          1      3
# 4      male  35.0      0      0   8.0500         1        5          0      1
# ..      ...   ...    ...    ...      ...       ...      ...        ...    ...
# 886    male  27.0      0      0  13.0000         1        5          0      6
# 887  female  19.0      0      0  30.0000         1        4          1      2
# 888  female   NaN      1      2  23.4500         1        4          0      2
# 889    male  26.0      0      0  30.0000         2        5          1      1
# 890    male  32.0      0      0   7.7500         3        5          0      1
#
# [891 rows x 12 columns]

# %%
df = df.drop(['Age', 'Name'], axis = 1)

# %% [markdown]
# ### Sex Feature

# %%
sex_mapping = {"male": 0 , "female": 1}

df['Sex'] = df['Sex'].map(sex_mapping)

df
# Out:
#      Survived  Pclass  Sex  SibSp  Parch     Fare  Embarked AgeGroup  \
# 0         0.0       3    0      1      0   7.2500         1        4
# 1         1.0       1    1      1      0  71.2833         2        6
# 2         1.0       3    1      0      0   7.9250         1        5
# 3         1.0       1    1      1      0  53.1000         1        5
# 4         0.0       3    0      0      0   8.0500         1        5
# ..        ...     ...  ...    ...    ...      ...       ...      ...
# 886       0.0       2    0      0      0  13.0000         1        5
# 887       1.0       1    1      0      0  30.0000         1        4
# 888       0.0       3    1      1      2  23.4500         1        4
# 889       1.0       1    0      0      0  30.0000         2        5
# 890       0.0       3    0      0      0   7.7500         3        5
#
#      CabinBool  Title
# 0            0      1
# 1            1      3
# 2            0      2
# 3            1      3
# 4            0      1
# ..         ...    ...
# 886          0      6
# 887          1      2
# 888          0      2
# 889          1      1
# 890          0      1
#
# [891 rows x 10 columns]

# %% [markdown]
# ### Fare Feature

# %%
print('Class 1 Fare(mean) -->', df[df["Pclass"] == 1]["Fare"].mean())
print('Class 2 Fare(mean) -->', df[df["Pclass"] == 2]["Fare"].mean())
print('Class 3 Fare(mean) -->', df[df["Pclass"] == 3]["Fare"].mean())
# Out:
# Class 1 Fare(mean) --> 84.1546875
# Class 2 Fare(mean) --> 20.662183152173913
# Class 3 Fare(mean) --> 13.675550101832993

# %%
class_fare_mapping = {1: 84.1547, 2: 20.6622, 3: 13.6756}

df['Fare'] = df['Fare'].fillna((df["Pclass"].map(class_fare_mapping)))

df
# Out:
#      Survived  Pclass  Sex  SibSp  Parch     Fare  Embarked AgeGroup  \
# 0         0.0       3    0      1      0   7.2500         1        4
# 1         1.0       1    1      1      0  71.2833         2        6
# 2         1.0       3    1      0      0   7.9250         1        5
# 3         1.0       1    1      1      0  53.1000         1        5
# 4         0.0       3    0      0      0   8.0500         1        5
# ..        ...     ...  ...    ...    ...      ...       ...      ...
# 886       0.0       2    0      0      0  13.0000         1        5
# 887       1.0       1    1      0      0  30.0000         1        4
# 888       0.0       3    1      1      2  23.4500         1        4
# 889       1.0       1    0      0      0  30.0000         2        5
# 890       0.0       3    0      0      0   7.7500         3        5
#
#      CabinBool  Title
# 0            0      1
# 1            1      3
# 2            0      2
# 3            1      3
# 4            0      1
# ..         ...    ...
# 886          0      6
# 887          1      2
# 888          0      2
# 889          1      1
# 890          0      1
#
# [891 rows x 10 columns]

# %%
maxi = df.Fare.max()
mini = df.Fare.min()

df['Fare'] = df['Fare']/(maxi - mini)

df
# Out:
#      Survived  Pclass  Sex  SibSp  Parch      Fare  Embarked AgeGroup  \
# 0         0.0       3    0      1      0  0.014151         1        4
# 1         1.0       1    1      1      0  0.139136         2        6
# 2         1.0       3    1      0      0  0.015469         1        5
# 3         1.0       1    1      1      0  0.103644         1        5
# 4         0.0       3    0      0      0  0.015713         1        5
# ..        ...     ...  ...    ...    ...       ...       ...      ...
# 886       0.0       2    0      0      0  0.025374         1        5
# 887       1.0       1    1      0      0  0.058556         1        4
# 888       0.0       3    1      1      2  0.045771         1        4
# 889       1.0       1    0      0      0  0.058556         2        5
# 890       0.0       3    0      0      0  0.015127         3        5
#
#      CabinBool  Title
# 0            0      1
# 1            1      3
# 2            0      2
# 3            1      3
# 4            0      1
# ..         ...    ...
# 886          0      6
# 887          1      2
# 888          0      2
# 889          1      1
# 890          0      1
#
# [891 rows x 10 columns]

# %% [markdown]
# ## CORRELATION PLOT

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ## TRAIN/TEST SPLIT

# %%
X = df.drop(['Survived'], axis=1).values
Y = df['Survived'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.22, random_state = 0)

# %%
x_train = np.array(x_train, dtype='int64')
y_train = np.array(y_train, dtype='int64')

x_test = np.array(x_test, dtype='int64')
y_test = np.array(y_test, dtype='int64')

# %% [markdown]
# ## MODELS

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

LR_model = LogisticRegression()
LR_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
evalu_LR = LR_model.score(x_test,y_test)
print('The accuracy of Logistic Regresion Model on Test Data-Set is = '"{:.2f}".format(evalu_LR*100), '%')
# Out:
# The accuracy of Logistic Regresion Model on Test Data-Set is = 79.19 %

# %% [markdown]
# ### Support Vector Machine(RBF Kernel)

# %%
from sklearn.svm import SVC

SVM_model_rbf = SVC()
SVM_model_rbf.fit(x_train,y_train)
# Out:
# SVC()

# %%
evalu_SVM_rbf = SVM_model_rbf.score(x_test,y_test)
print('The accuracy of Support Vector Machine(RBF) Model on Test Data-Set is = '"{:.2f}".format(evalu_SVM_rbf*100), '%')
# Out:
# The accuracy of Support Vector Machine(RBF) Model on Test Data-Set is = 83.76 %

# %% [markdown]
# ### Support Vector Machine(Linear Kernel)

# %%
from sklearn.svm import SVC

SVM_model_l = SVC(kernel='linear')
SVM_model_l.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
evalu_SVM_l = SVM_model_l.score(x_test,y_test)
print('The accuracy of Support Vector Machine(linear) Model on Test Data-Set is = '"{:.2f}".format(evalu_SVM_l*100), '%')
# Out:
# The accuracy of Support Vector Machine(linear) Model on Test Data-Set is = 79.19 %

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

DTC_model = DecisionTreeClassifier(criterion='entropy')
DTC_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
evalu_DTC = DTC_model.score(x_test,y_test)
print('The accuracy of Decision Tree Classifier¶ Model on Test Data-Set is = '"{:.2f}".format(evalu_DTC*100), '%')
# Out:
# The accuracy of Decision Tree Classifier¶ Model on Test Data-Set is = 77.66 %

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

RFC_model = RandomForestClassifier(n_estimators=20)
RFC_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
evalu_RFC = RFC_model.score(x_test,y_test)
print('The accuracy of Random Forest Classifier Model on Test Data-Set is = '"{:.2f}".format(evalu_RFC*100), '%')
# Out:
# The accuracy of Random Forest Classifier Model on Test Data-Set is = 80.20 %

# %% [markdown]
# ### K-Nearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN_model = KNeighborsClassifier(n_neighbors=9)
KNN_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
evalu_KNN = KNN_model.score(x_test,y_test)
print('The accuracy of K-Nearest Neighbour Model on Test Data-Set is = '"{:.2f}".format(evalu_KNN*100), '%')
# Out:
# The accuracy of K-Nearest Neighbour Model on Test Data-Set is = 84.26 %

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

NB_model = MultinomialNB()
NB_model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
evalu_NB = NB_model.score(x_test,y_test)
print('The accuracy of Multinomial Naive Bayes Model on Test Data-Set is = '"{:.2f}".format(evalu_NB*100), '%')
# Out:
# The accuracy of Multinomial Naive Bayes Model on Test Data-Set is = 78.17 %
